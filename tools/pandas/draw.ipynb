# %%
# %pylab inline
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from pandas import *
from numpy import *

# %%
random.seed(123456)

# %%
ts = Series(randn(1000), index=date_range('1/1/2000', periods=1000))
ts
# Out:
# 2000-01-01    1.994515
# 2000-01-02    0.346823
# 2000-01-03    0.354734
# 2000-01-04    1.185464
# 2000-01-05   -0.799739
# 2000-01-06    0.438302
# 2000-01-07    1.020395
# 2000-01-08   -0.584339
# 2000-01-09   -0.504424
# 2000-01-10   -1.091023
# 2000-01-11   -0.224136
# 2000-01-12   -0.379561
# 2000-01-13    0.682261
# 2000-01-14    0.475287
# 2000-01-15   -1.457001
# 2000-01-16    1.557417
# 2000-01-17    0.991843
# 2000-01-18   -1.198124
# 2000-01-19   -0.060144
# 2000-01-20   -1.802440
# 2000-01-21   -0.621617
# 2000-01-22   -0.800501
# 2000-01-23   -1.853522
# 2000-01-24   -0.965462
# 2000-01-25    0.927405
# 2000-01-26   -0.252740
# 2000-01-27   -0.905208
# 2000-01-28    1.331948
# 2000-01-29    0.408966
# 2000-01-30   -1.105118
#                 ...
# 2002-08-28    0.500523
# 2002-08-29    0.946314
# 2002-08-30    0.370261
# 2002-08-31    0.623718
# 2002-09-01   -0.157861
# 2002-09-02   -0.656963
# 2002-09-03    0.577936
# 2002-09-04   -0.300969
# 2002-09-05   -1.572001
# 2002-09-06    0.990038
# 2002-09-07   -1.527278
# 2002-09-08    0.062820
# 2002-09-09   -0.743567
# 2002-09-10   -1.705873
# 2002-09-11   -0.312793
# 2002-09-12    0.800778
# 2002-09-13   -1.084734
# 2002-09-14   -0.044215
# 2002-09-15   -0.204983
# 2002-09-16   -1.314436
# 2002-09-17   -0.622222
# 2002-09-18   -0.560648
# 2002-09-19    0.005935
# 2002-09-20    1.252874
# 2002-09-21   -2.017178
# 2002-09-22   -1.064431
# 2002-09-23   -0.499125
# 2002-09-24   -1.914913
# 2002-09-25    1.443152
# 2002-09-26    0.657525
# Freq: D, dtype: float64

# %%
ts.plot()

# %%
df = DataFrame(randn(1000, 4), index=ts.index, columns=list('ABCD'))

df = df.cumsum()
df.plot()

# %%
df3 = DataFrame(randn(1000, 2), columns=['B', 'C']).cumsum()
df3['A'] = Series(list(range(len(df))))
df3.plot(x='A', y='B')

# %%
df.ix[5].plot(kind='bar'); plt.axhline(0, color='k')

# %%
df2 = DataFrame(rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot(kind='bar');

# %%
df2.plot(kind='bar', stacked=True);

# %%
df2.plot(kind='barh', stacked=True);

# %%
df4 = DataFrame({'a': randn(1000) + 1, 'b': randn(1000),
                 'c': randn(1000) - 1}, columns=['a', 'b', 'c'])
df4
# Out:
#             a         b         c
# 0   -0.139222  0.592142 -0.623007
# 1    1.354653  0.651032 -0.771937
# 2    1.563622 -0.113654 -2.720421
# 3    0.634894 -0.276894  1.024104
# 4    2.092702  1.610249 -0.877581
# 5   -0.481449  0.106333 -1.158910
# 6    2.781190  0.712162 -1.019481
# 7    0.968457 -0.351275  0.263240
# 8    1.480993  1.176287 -0.831294
# 9    1.604244  2.039210 -0.919677
# 10   0.512735  1.741787 -1.209886
# 11   2.990533 -1.301869 -0.898653
# 12   1.327007  0.612432 -2.558154
# 13   2.053639 -0.577677 -0.918359
# 14  -1.927808  0.124709 -0.863872
# 15   1.082065  1.188253  0.046353
# 16   1.456554 -1.068084 -0.501004
# 17  -0.757911 -0.899627 -0.781198
# 18   1.982407  0.822023 -0.683360
# 19   1.339642  1.506319 -3.280022
# 20   2.499953  0.998896 -1.776417
# 21   0.682182  0.302152 -1.137809
# 22   1.447371  0.259080 -0.554181
# 23  -0.315799 -0.522705  0.258437
# 24   0.323447 -1.473680 -1.529003
# 25   1.345770 -1.726800 -2.002564
# 26   1.167060  1.555343 -2.872671
# 27   1.008525 -1.674446 -1.808307
# 28   2.073216 -1.411978 -2.172882
# 29   0.655437  0.733147 -1.051295
# ..        ...       ...       ...
# 970  3.486059  0.069982 -3.264283
# 971  1.876661 -0.736209 -0.224575
# 972  0.888116 -0.185835 -1.933861
# 973  0.167362  1.257633 -0.293197
# 974  2.569224 -2.213589 -0.901415
# 975  0.825576 -0.476218  0.814259
# 976  2.724552  1.149266 -1.069898
# 977  2.672716  0.689057 -1.504304
# 978  0.589239 -1.606896 -2.644132
# 979  1.840845 -0.315377 -0.798496
# 980  0.143100 -0.113059 -1.640879
# 981  1.074786 -0.343981 -1.146394
# 982 -0.609521 -1.076052 -1.049842
# 983  2.103200 -0.393720 -1.136642
# 984  1.457043  0.569096 -1.745347
# 985  0.263337  0.458945 -0.463527
# 986  1.862940  1.490909  0.641064
# 987  0.683745 -1.095239 -1.824669
# 988  2.881594 -1.036124 -1.069451
# 989 -0.432070 -1.423169 -1.344566
# 990  2.390184  1.887391  1.841584
# 991  2.676797  0.408678 -0.999483
# 992 -0.237506  1.660367 -1.456984
# 993 -1.077825  1.144633  1.193373
# 994  0.389432 -0.955400  2.660044
# 995  1.261380 -0.102952  0.744555
# 996  1.348727 -1.312014 -2.265255
# 997  0.452560 -1.096775  0.525815
# 998  1.015586 -0.140608 -0.698675
# 999  1.181152 -1.598695 -1.207593
#
# [1000 rows x 3 columns]

# %%
df4.plot(kind='hist', alpha=0.5)

# %%
df4.plot(kind='hist', stacked=True, bins=20)

# %%
df4['a'].plot(kind='hist', orientation='horizontal', cumulative=True)

# %%
 df['A'].diff().hist()

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1074d30d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107522790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1077abc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10781c610>]], dtype=object)

# %%
data = Series(randn(1000))

# %%
 data.hist(by=randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1079aac50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x106c42d90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x107b61d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x107bd1050>]], dtype=object)

# %%
df = DataFrame(rand(10, 5), columns=['A', 'B', 'C', 'D', 'E'])

# %%
df.plot(kind='box')

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange',
             medians='DarkBlue', caps='Gray')

# %%
df.plot(kind='box', color=color, sym='r+')

# %%
 df.plot(kind='box', vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = DataFrame(rand(10,2), columns=['Col1', 'Col2'] )

df['X'] = Series(['A','A','A','A','A','B','B','B','B','B'])
bp = df.boxplot(by='X')

# %%
df = DataFrame(rand(10,3), columns=['Col1', 'Col2', 'Col3'])

df['X'] = Series(['A','A','A','A','A','B','B','B','B','B'])

df['Y'] = Series(['A','B','A','B','A','B','A','B','A','B'])

plt.figure();

bp = df.boxplot(column=['Col1','Col2'], by=['X','Y'])

# %%
np.random.seed(1234)

df_box = DataFrame(np.random.randn(50, 2))

df_box['g'] = np.random.choice(['A', 'B'], size=50)

df_box.loc[df_box['g'] == 'B', 1] += 3

bp = df_box.boxplot(by='g')

# %%
df = DataFrame(rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot(kind='area');

# %%
df.plot(kind='area', stacked=False);

# %%
df = DataFrame(rand(50, 4), columns=['a', 'b', 'c', 'd'])
df.plot(kind='scatter', x='a', y='b');

# %%
ax = df.plot(kind='scatter', x='a', y='b',
             color='DarkBlue', label='Group 1');
df.plot(kind='scatter', x='c', y='d',
        color='DarkGreen', label='Group 2', ax=ax);

# %%
df.plot(kind='scatter', x='a', y='b', c='c', s=50);

# %%
df.plot(kind='scatter', x='a', y='b', s=df['c']*200);

# %%
df = DataFrame(randn(1000, 2), columns=['a', 'b'])

df['b'] = df['b'] + np.arange(1000)

df.plot(kind='hexbin', x='a', y='b', gridsize=25)

# %%
series = Series(3 * rand(4), index=['a', 'b', 'c', 'd'], name='series')

series.plot(kind='pie', figsize=(6, 6))

# %%
df = DataFrame(3 * rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])
df.plot(kind='pie', subplots=True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1086fe550>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x108dff4d0>], dtype=object)

# %%
series = Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')

series.plot(kind='pie', figsize=(6, 6))

# %%
from pandas.tools.plotting import scatter_matrix

df = DataFrame(randn(1000, 4), columns=['a', 'b', 'c', 'd'])

scatter_matrix(df, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x108d6f790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10911ddd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1091f8850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1083bb810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1086c2c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1082d2e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1086c5550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1087b1490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x108b89ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1089f6ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1085c2dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x109281c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1092f1950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1093798d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1093ed090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1094720d0>]], dtype=object)

# %%
ser = Series(randn(1000))

ser.plot(kind='kde')

# %%
from pandas import read_csv

from pandas.tools.plotting import andrews_curves

data = read_csv('data/iris.data')

#andrews_curves(data, 'Name')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-59-7a35e4c701be> in <module>()
#       3 from pandas.tools.plotting import andrews_curves
#       4
# ----> 5 data = read_csv('data/iris.data')
#       6
#       7 #andrews_curves(data, 'Name')
#
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# /usr/local/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# IOError: File data/iris.data does not exist

# %%
from pandas.tools.plotting import lag_plot

plt.figure()
data = Series(0.1 * rand(1000) +
   0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))
lag_plot(data)
